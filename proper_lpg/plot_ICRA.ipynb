# %%
extro= [10,5,8.5,8.5,10,5,8.5,8.5,10,5,5,10,5,10,10]
unsc=[-10,-7,-4.9,-9.9,-8.4,-5.4,-3.3,-8.3,-6.8,-3.8,-8.8,-7.3,-4.3,-4.3,-9.3]
dur=[10,7,5,5,10,7,5,5,10,5,5,10,5,5]

# %%
len(extro), len(dur)
# Out:
# (15, 14)

# %%
time=[0]
for d in dur:
    a_t=time[-1]+d
    time.append(a_t)

# %%
import matplotlib.pyplot as plt
plt.plot(time,extro)
plt.scatter(time,extro)
plt.plot(time,len(time)*[5])
text=["MOVE","PRESENT THE TASK", "SAY BE CALM ABOUT THE WORK","ASK PICK THE BLOCK VOICE", "MOVE","PRESENT THE TASK", "MOVE RANDOMLY", "ASK ASSEMBLY A BLOCK","MOVE","CHAT","ASK PICK THE BLOCK VOICE","MOVE","EXPESS ENTHUSIASM", "LATE"]
for i in range(0,len(time)-1):
    print(text[i])
    plt.text(100,10-i*0.3,text[i])
# Out:
# MOVE
# PRESENT THE TASK
# SAY BE CALM ABOUT THE WORK
# ASK PICK THE BLOCK VOICE
# MOVE
# PRESENT THE TASK
# MOVE RANDOMLY
# ASK ASSEMBLY A BLOCK
# MOVE
# CHAT
# ASK PICK THE BLOCK VOICE
# MOVE
# EXPESS ENTHUSIASM
# LATE

# %%
import matplotlib.pyplot as plt
plt.plot(time,unsc)
plt.plot(time,len(time)*[-5])
