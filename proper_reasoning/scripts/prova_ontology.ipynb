# %%
from load_ontology import *

# %%
traits=["Extrovert","Introvert","Conscientious","Unscrupolous","Agreeable","Disagreeable"]
traits_preds=["(extro)","(intro)","(consc)","(unsc)","(agree)","(disagree)"]
we=1
wi=0
wc=0
wu=1
wa=0
wd=0
sum_weights=0
sum_weights=float(we +wi +wc + wu + wa + wd)
try: 
        weights=[we/sum_weights,wi/sum_weights,wc/sum_weights,wu/sum_weights,wa/sum_weights,wd/sum_weights]
except:
        weights=6*[0]
        sum_weights=1
gamma=1


with open('/home/alice/PROPER_Sofar/proper_reasoning/init_problem.pddl','r') as firstfile, open('/home/alice/PROPER_Sofar/proper_reasoning/prova_problem.pddl','w') as secondfile:
    for line in firstfile:
    
        if "extroversion_coefficient" in line:
            if we!=0.0:
                l="        (= (extroversion_coefficient) "+str(weights[0]) +")\n"
                secondfile.write(l)
                p="        "+traits_preds[0]+"\n"
                secondfile.write(p)
            else:
                print(str(gamma*(wi/sum_weights)))
                l="        (= (extroversion_coefficient) "+str(weights[1]) +")\n"
                secondfile.write(l)
                p="        "+traits_preds[1]+"\n"
                secondfile.write(p)
        elif "conscientious_coefficient" in line:
            if wc!=0.0:
                l="        (= (conscientious_coefficient) "+str(weights[2]) +")\n"
                secondfile.write(l)
                p="        "+traits_preds[2]+"\n"
                secondfile.write(p)
            else:
                print(gamma*(wu/sum_weights))
                l="        (= (conscientious_coefficient) "+str(weights[3]) +")\n"
                secondfile.write(l)
                p="        "+traits_preds[3]+"\n"
                secondfile.write(p)
        elif "agreeableness_coefficient" in line:
            if wa!=0:
                l="        (= (agreeableness_coefficient) "+str(weights[4]) +")\n"
                secondfile.write(l)
                p="        "+traits_preds[4]+"\n"
                secondfile.write(p)
            else:
                l="        (= (agreeableness_coefficient) "+str(weights[5]) +")\n"
                secondfile.write(l)
                p="        "+traits_preds[5]+"\n"
                secondfile.write(p)
        else:
            secondfile.write(line)
print('Reading domain and populate ontology')
populate_ontology('/home/alice/PROPER_Sofar/proper_reasoning/goal1_domain.pddl')
print('Initialize function and predicates in the ontology')
initialize_functions_predicates()
print('Read the problem and set the initial values of predicates and functions')
read_the_problem('/home/alice/PROPER_Sofar/proper_reasoning/prova_problem.pddl')
# Out:
# 0.5
# Reading domain and populate ontology
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# hello there
# True
# read param
# ['?p', '', 'person']
# find a new param
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# hello there
# True
# read param
# ['?p', '', 'person']
# find a new param
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# hello there
# True
# read param
# ['', '?p', '', 'person']
# find a new param
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# hello there
# True
# read param
# ['?p', '', 'person']
# find a new param
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# hello there
# True
# read param
# ['?p', '', 'person']
# find a new param
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# hello there
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# Initialize function and predicates in the ontology
# Read the problem and set the initial values of predicates and functions
# ['=', 'dur', '5']
# ['=', 'dur', '5']
# ['=', 'react', '2']
# ['=', 'react', '2']
# ['=', 'reward_e', '5']
# ['=', 'reward_e', '5']
# ['=', 'reward_a', '5']
# ['=', 'reward_a', '5']
# ['=', 'reward_c', '5']
# ['=', 'reward_c', '5']
# ['=', 'extroversion_coefficient', '0.5']
# ['=', 'extroversion_coefficient', '0.5']
# ['extro']
# ['extro']
# ['=', 'desired_interaction', '5']
# ['=', 'desired_interaction', '5']
# ['=', 'interaction_level', '6']
# ['=', 'interaction_level', '6']
# ['=', 'conscientious_coefficient', '0.5']
# ['=', 'conscientious_coefficient', '0.5']
# ['unsc']
# ['unsc']
# ['=', 'desired_scrupulousness', '5']
# ['=', 'desired_scrupulousness', '5']
# ['=', 'scrupulousness_level', '6']
# ['=', 'scrupulousness_level', '6']
# ['=', 'agreeableness_coefficient', '0.0']
# ['=', 'agreeableness_coefficient', '0.0']
# ['disagree']
# ['disagree']
# ['=', 'desired_agreeableness', '5']
# ['=', 'desired_agreeableness', '5']
# ['=', 'agreeableness_level', '6']
# ['=', 'agreeableness_level', '6']
# ['emotion_r']
# ['emotion_r']
# ['attention_r']
# ['attention_r']
# ['low_attention_r']
# ['low_attention_r']
# ['answered']
# ['answered']
# []
# []

# %%
def add_person(name):

    objects_objects[name]=Objects(name)
    objects_objects[name].has_type=[types_objects["person"]]
    predicates_objects["person_present"].is_grounded=True
    predicates_objects["person_present"].has_object.append(objects_objects[name])
    predicates_objects["person_there"].is_grounded=True
    predicates_objects["person_there"].has_object=[]
    predicates_objects["person_there"].has_object.append(objects_objects[name])

# %%
remove_predicate("person_there")
add_predicate("finished")

# %%
add_person("fabio")
add_goal("finished")
remove_predicate("finished")
remove_predicate("welcomed")

# %%
update_problem('/home/alice/PROPER_Sofar/proper_reasoning/prova_problem.pddl')
# Out:
# goal1.answered
# goal1.person_present
# goal1.person_there
# goal1.extro
# goal1.unsc
# goal1.disagree
# goal1.emotion_r
# goal1.attention_r
# goal1.low_attention_r
# written

# %%
return_code=planning('./ff -p /home/alice/PROPER_Sofar/proper_reasoning/ -o goal1_domain.pddl -f prova_problem.pddl','/home/alice/PROPER_Sofar/proper_reasoning/',"/home/alice/PROPER_Sofar/proper_reasoning/plan.pddl")

# %%
read_plan("/home/alice/PROPER_Sofar/proper_reasoning/plan.pddl")
# Out:
# ['GREET FABIO',
#  'ASK_PRESENT FABIO',
#  'UNSC_ACTION',
#  'EXTRO_ACTION',
#  'PRESENT_LAB FABIO',
#  'ASK_PREFERENCES FABIO',
#  'UNSC_ACTION',
#  'EXTRO_ACTION',
#  'GIVE_NEW_INFO FABIO',
#  'UNSC_ACTION',
#  'EXTRO_ACTION',
#  'CHECK_FINISH FABIO']

# %%
update_ontology("GREET FABIO")
# Out:
# [goal1.greetings, goal1.welcomed, goal1.person_present, goal1.answered]
# removed
# goal1.fabio
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 update_ontology("GREET FABIO")
#
# File ~/PROPER_Sofar/proper_reasoning/scripts/load_ontology.py:485, in update_ontology(a)
#     483 print("removed")
#     484 print(objects_objects[params[parameters_objects[o[2]].has_order-1].lower()])
# --> 485 p.has_object.remove(objects_objects[params[parameters_objects[o[2]].has_order-1].lower()])
#     486 if(len(p.has_object))>=1:
#     487     p.is_grounded=True
#
# File ~/.local/lib/python3.8/site-packages/owlready2/util.py:92, in CallbackList.remove(self, x)
# ---> 92 def remove(self, x):        old = list(self); super().remove(x)         ; self._callback(self._obj, old)
#
# ValueError: list.remove(x): x not in list

# %%
actions_objects["GREET"].has_effect_predicates

# %%
len(predicates_objects["greetings"].has_object)
